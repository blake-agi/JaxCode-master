# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR-GITHUB-USERNAME/JAXCode/blob/master/templates/00_welcome.ipynb)
#
# # ⚡ Welcome to JAXCode
#
# **Crack the JAX interview.** Implement operators, layers and training
# machinery from scratch — in JAX and Flax NNX.
#
# **52 problems** — 🟢 13 Easy · 🟡 19 Medium · 🔴 20 Hard
#
# ---
#
# ## How it works
#
# 1. Open a numbered notebook
# 2. Fill in the function or `nnx.Module` in the ✏️ cell
# 3. Run the ✅ submit cell — the judge runs the real test suite
#
# ```python
# from jax_judge import check, hint, solution, status, reset_progress
#
# status()             # dashboard of every problem and your progress
# check("relu")        # grade your implementation
# hint("relu")         # a nudge, not the answer
# solution("relu")     # spoiler: the reference implementation
# ```
#
# ---
#
# ## The problems
#
#
# ### JAX Fundamentals
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 01 | [SGD Step with value_and_grad](01_grad_basics.ipynb) | 🟢 Easy | `grad_basics` |
# | 02 | [Pairwise Distances with vmap](02_vmap_batching.ipynb) | 🟢 Easy | `vmap_batching` |
# | 03 | [jit with static_argnames](03_jit_static.ipynb) | 🟢 Easy | `jit_static` |
# | 04 | [Stack a List of Pytrees](04_pytree_ops.ipynb) | 🟡 Medium | `pytree_ops` |
# | 05 | [PRNG Keys and Splitting](05_prng_keys.ipynb) | 🟢 Easy | `prng_keys` |
# | 06 | [Discounted Returns with lax.scan](06_lax_scan.ipynb) | 🟡 Medium | `lax_scan` |
# | 07 | [Newton's Method with lax.while_loop](07_lax_control_flow.ipynb) | 🟡 Medium | `lax_control_flow` |
# | 08 | [Stable log(1+exp(x)) with custom_vjp](08_custom_vjp.ipynb) | 🔴 Hard | `custom_vjp` |
# | 09 | [Hessian with jacfwd(jacrev(f))](09_higher_order_grad.ipynb) | 🟡 Medium | `higher_order_grad` |
# | 10 | [Gradient Checkpointing with jax.checkpoint](10_remat_checkpoint.ipynb) | 🟡 Medium | `remat_checkpoint` |
# | 11 | [Data-Parallel Mean with shard_map](11_sharding_basics.ipynb) | 🔴 Hard | `sharding_basics` |
#
# ### Core Ops & Layers
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 12 | [Implement ReLU](12_relu.ipynb) | 🟢 Easy | `relu` |
# | 13 | [GELU Activation](13_gelu.ipynb) | 🟢 Easy | `gelu` |
# | 14 | [Implement Softmax](14_softmax.ipynb) | 🟢 Easy | `softmax` |
# | 15 | [Simple Linear Layer](15_linear.ipynb) | 🟡 Medium | `linear` |
# | 16 | [Implement LayerNorm](16_layernorm.ipynb) | 🟡 Medium | `layernorm` |
# | 17 | [Implement RMSNorm](17_rmsnorm.ipynb) | 🟡 Medium | `rmsnorm` |
# | 18 | [Implement BatchNorm](18_batchnorm.ipynb) | 🟡 Medium | `batchnorm` |
# | 19 | [Implement Dropout](19_dropout.ipynb) | 🟢 Easy | `dropout` |
# | 20 | [Embedding Layer](20_embedding.ipynb) | 🟢 Easy | `embedding` |
# | 21 | [SwiGLU MLP](21_mlp.ipynb) | 🟡 Medium | `mlp` |
# | 22 | [Kaiming Initialization](22_weight_init.ipynb) | 🟢 Easy | `weight_init` |
# | 23 | [2D Convolution](23_conv2d.ipynb) | 🟡 Medium | `conv2d` |
#
# ### Attention & Transformers
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 24 | [Softmax Attention](24_attention.ipynb) | 🔴 Hard | `attention` |
# | 25 | [Multi-Head Attention](25_mha.ipynb) | 🔴 Hard | `mha` |
# | 26 | [Causal Self-Attention](26_causal_attention.ipynb) | 🔴 Hard | `causal_attention` |
# | 27 | [Multi-Head Cross-Attention](27_cross_attention.ipynb) | 🟡 Medium | `cross_attention` |
# | 28 | [Grouped Query Attention](28_gqa.ipynb) | 🔴 Hard | `gqa` |
# | 29 | [Sliding Window Attention](29_sliding_window.ipynb) | 🔴 Hard | `sliding_window` |
# | 30 | [Linear Self-Attention](30_linear_attention.ipynb) | 🔴 Hard | `linear_attention` |
# | 31 | [Flash Attention (Tiled)](31_flash_attention.ipynb) | 🔴 Hard | `flash_attention` |
# | 32 | [Rotary Position Embedding (RoPE)](32_rope.ipynb) | 🔴 Hard | `rope` |
# | 33 | [KV Cache Attention](33_kv_cache.ipynb) | 🔴 Hard | `kv_cache` |
# | 34 | [GPT-2 Transformer Block](34_gpt2_block.ipynb) | 🔴 Hard | `gpt2_block` |
# | 35 | [ViT Patch Embedding](35_vit_patch.ipynb) | 🟡 Medium | `vit_patch` |
# | 36 | [Mixture of Experts (MoE)](36_moe.ipynb) | 🔴 Hard | `moe` |
# | 37 | [LoRA (Low-Rank Adaptation)](37_lora.ipynb) | 🟡 Medium | `lora` |
#
# ### Training
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 38 | [Cross-Entropy Loss](38_cross_entropy.ipynb) | 🟢 Easy | `cross_entropy` |
# | 39 | [Linear Regression](39_linear_regression.ipynb) | 🟡 Medium | `linear_regression` |
# | 40 | [Adam Optimizer](40_adam.ipynb) | 🟡 Medium | `adam` |
# | 41 | [Cosine LR Scheduler with Warmup](41_cosine_lr.ipynb) | 🟡 Medium | `cosine_lr` |
# | 42 | [Gradient Norm Clipping](42_gradient_clipping.ipynb) | 🟢 Easy | `gradient_clipping` |
# | 43 | [Gradient Accumulation](43_gradient_accumulation.ipynb) | 🟢 Easy | `gradient_accumulation` |
#
# ### Inference & Decoding
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 44 | [Top-k / Top-p Sampling](44_topk_sampling.ipynb) | 🟡 Medium | `topk_sampling` |
# | 45 | [Beam Search Decoding](45_beam_search.ipynb) | 🟡 Medium | `beam_search` |
# | 46 | [Speculative Decoding](46_speculative_decoding.ipynb) | 🔴 Hard | `speculative_decoding` |
# | 47 | [Byte-Pair Encoding (BPE)](47_bpe.ipynb) | 🔴 Hard | `bpe` |
# | 48 | [INT8 Quantized Linear](48_int8_quantization.ipynb) | 🔴 Hard | `int8_quantization` |
#
# ### RLHF & Preference Losses
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 49 | [DPO (Direct Preference Optimization) Loss](49_dpo_loss.ipynb) | 🔴 Hard | `dpo_loss` |
# | 50 | [GRPO (Group Relative Policy Optimization) Loss](50_grpo_loss.ipynb) | 🔴 Hard | `grpo_loss` |
# | 51 | [PPO (Proximal Policy Optimization) Clipped Loss](51_ppo_loss.ipynb) | 🔴 Hard | `ppo_loss` |
# | 52 | [OPD (On-Policy Distillation) Loss](52_opd_loss.ipynb) | 🔴 Hard | `opd_loss` |
#
# ---
#
# ## Suggested route
#
# Work **JAX Fundamentals** first even if you know the ML content cold —
# the rest of the problems assume you are fluent with `vmap`, `scan`,
# pytrees and explicit PRNG keys. After that, follow the categories in
# order or jump to whatever your interview is targeting.

# %%
# Your progress dashboard
from jax_judge import status

status()
