# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR-GITHUB-USERNAME/JAXCode/blob/master/templates/00_welcome.ipynb)
#
# # ⚡ Welcome to JAXCode
#
# **Crack the JAX interview.** Implement operators, layers and training
# machinery from scratch — in JAX and Flax NNX.
#
# **52 problems** — 🟢 13 Easy · 🟡 19 Medium · 🔴 20 Hard
#
# ---
#
# ## How it works
#
# 1. Open a numbered notebook
# 2. Fill in the function or `nnx.Module` in the ✏️ cell
# 3. Run the ✅ submit cell — the judge runs the real test suite
#
# ```python
# from jax_judge import check, hint, solution, status, reset_progress
#
# status()             # dashboard of every problem and your progress
# check("relu")        # grade your implementation
# hint("relu")         # a nudge, not the answer
# solution("relu")     # spoiler: the reference implementation
# ```
#
# ---
#
# ## The problems
#
#
# ### JAX Fundamentals
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | b_01 | [SGD Step with value_and_grad](b_01_grad_basics.ipynb) | 🟢 Easy | `grad_basics` |
# | b_02 | [Pairwise Distances with vmap](b_02_vmap_batching.ipynb) | 🟢 Easy | `vmap_batching` |
# | b_03 | [jit with static_argnames](b_03_jit_static.ipynb) | 🟢 Easy | `jit_static` |
# | b_04 | [Stack a List of Pytrees](b_04_pytree_ops.ipynb) | 🟡 Medium | `pytree_ops` |
# | b_05 | [PRNG Keys and Splitting](b_05_prng_keys.ipynb) | 🟢 Easy | `prng_keys` |
# | b_06 | [Discounted Returns with lax.scan](b_06_lax_scan.ipynb) | 🟡 Medium | `lax_scan` |
# | b_07 | [Newton's Method with lax.while_loop](b_07_lax_control_flow.ipynb) | 🟡 Medium | `lax_control_flow` |
# | b_08 | [Stable log(1+exp(x)) with custom_vjp](b_08_custom_vjp.ipynb) | 🔴 Hard | `custom_vjp` |
# | b_09 | [Hessian with jacfwd(jacrev(f))](b_09_higher_order_grad.ipynb) | 🟡 Medium | `higher_order_grad` |
# | b_10 | [Gradient Checkpointing with jax.checkpoint](b_10_remat_checkpoint.ipynb) | 🟡 Medium | `remat_checkpoint` |
# | b_11 | [Data-Parallel Mean with shard_map](b_11_sharding_basics.ipynb) | 🔴 Hard | `sharding_basics` |
#
# ### Core Ops & Layers
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 01 | [Implement ReLU](01_relu.ipynb) | 🟢 Easy | `relu` |
# | 02 | [Implement Softmax](02_softmax.ipynb) | 🟢 Easy | `softmax` |
# | 03 | [Simple Linear Layer](03_linear.ipynb) | 🟡 Medium | `linear` |
# | 04 | [Implement LayerNorm](04_layernorm.ipynb) | 🟡 Medium | `layernorm` |
# | 07 | [Implement BatchNorm](07_batchnorm.ipynb) | 🟡 Medium | `batchnorm` |
# | 08 | [Implement RMSNorm](08_rmsnorm.ipynb) | 🟡 Medium | `rmsnorm` |
# | 15 | [SwiGLU MLP](15_mlp.ipynb) | 🟡 Medium | `mlp` |
# | 17 | [Implement Dropout](17_dropout.ipynb) | 🟢 Easy | `dropout` |
# | 18 | [Embedding Layer](18_embedding.ipynb) | 🟢 Easy | `embedding` |
# | 19 | [GELU Activation](19_gelu.ipynb) | 🟢 Easy | `gelu` |
# | 20 | [Kaiming Initialization](20_weight_init.ipynb) | 🟢 Easy | `weight_init` |
# | 22 | [2D Convolution](22_conv2d.ipynb) | 🟡 Medium | `conv2d` |
#
# ### Attention & Transformers
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 05 | [Softmax Attention](05_attention.ipynb) | 🔴 Hard | `attention` |
# | 06 | [Multi-Head Attention](06_mha.ipynb) | 🔴 Hard | `mha` |
# | 09 | [Causal Self-Attention](09_causal_attention.ipynb) | 🔴 Hard | `causal_attention` |
# | 10 | [Grouped Query Attention](10_gqa.ipynb) | 🔴 Hard | `gqa` |
# | 11 | [Sliding Window Attention](11_sliding_window.ipynb) | 🔴 Hard | `sliding_window` |
# | 12 | [Linear Self-Attention](12_linear_attention.ipynb) | 🔴 Hard | `linear_attention` |
# | 13 | [GPT-2 Transformer Block](13_gpt2_block.ipynb) | 🔴 Hard | `gpt2_block` |
# | 14 | [KV Cache Attention](14_kv_cache.ipynb) | 🔴 Hard | `kv_cache` |
# | 23 | [Multi-Head Cross-Attention](23_cross_attention.ipynb) | 🟡 Medium | `cross_attention` |
# | 24 | [Rotary Position Embedding (RoPE)](24_rope.ipynb) | 🔴 Hard | `rope` |
# | 25 | [Flash Attention (Tiled)](25_flash_attention.ipynb) | 🔴 Hard | `flash_attention` |
# | 26 | [LoRA (Low-Rank Adaptation)](26_lora.ipynb) | 🟡 Medium | `lora` |
# | 27 | [ViT Patch Embedding](27_vit_patch.ipynb) | 🟡 Medium | `vit_patch` |
# | 28 | [Mixture of Experts (MoE)](28_moe.ipynb) | 🔴 Hard | `moe` |
#
# ### Training
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 16 | [Cross-Entropy Loss](16_cross_entropy.ipynb) | 🟢 Easy | `cross_entropy` |
# | 21 | [Gradient Norm Clipping](21_gradient_clipping.ipynb) | 🟢 Easy | `gradient_clipping` |
# | 29 | [Implement Adam Optimizer](29_adam.ipynb) | 🟡 Medium | `adam` |
# | 30 | [Cosine LR Scheduler with Warmup](30_cosine_lr.ipynb) | 🟡 Medium | `cosine_lr` |
# | 31 | [Gradient Accumulation](31_gradient_accumulation.ipynb) | 🟢 Easy | `gradient_accumulation` |
# | 40 | [Linear Regression](40_linear_regression.ipynb) | 🟡 Medium | `linear_regression` |
#
# ### Inference & Decoding
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 32 | [Top-k / Top-p Sampling](32_topk_sampling.ipynb) | 🟡 Medium | `topk_sampling` |
# | 33 | [Beam Search Decoding](33_beam_search.ipynb) | 🟡 Medium | `beam_search` |
# | 34 | [Speculative Decoding](34_speculative_decoding.ipynb) | 🔴 Hard | `speculative_decoding` |
# | 35 | [Byte-Pair Encoding (BPE)](35_bpe.ipynb) | 🔴 Hard | `bpe` |
# | 36 | [INT8 Quantized Linear](36_int8_quantization.ipynb) | 🔴 Hard | `int8_quantization` |
#
# ### RLHF & Preference Losses
#
# | # | Problem | Difficulty | Task id |
# |---|---|---|---|
# | 37 | [DPO (Direct Preference Optimization) Loss](37_dpo_loss.ipynb) | 🔴 Hard | `dpo_loss` |
# | 38 | [GRPO (Group Relative Policy Optimization) Loss](38_grpo_loss.ipynb) | 🔴 Hard | `grpo_loss` |
# | 39 | [PPO (Proximal Policy Optimization) Clipped Loss](39_ppo_loss.ipynb) | 🔴 Hard | `ppo_loss` |
# | 41 | [OPD (On-Policy Distillation) Loss](41_opd_loss.ipynb) | 🔴 Hard | `opd_loss` |
#
# ---
#
# ## Suggested route
#
# Work **JAX Fundamentals** first even if you know the ML content cold —
# the rest of the problems assume you are fluent with `vmap`, `scan`,
# pytrees and explicit PRNG keys. After that, follow the categories in
# order or jump to whatever your interview is targeting.

# %%
# Your progress dashboard
from jax_judge import status

status()
