# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR-GITHUB-USERNAME/JAXCode/blob/master/templates/01_grad_basics.ipynb)
#
# # 🟢 Easy: SGD Step with value_and_grad
#
# *JAX Fundamentals*
# Implement a single **stochastic gradient descent step**.
#
# This is the innermost loop of essentially every JAX training script — if you
# only learn one JAX idiom, learn this one.
#
# Given a loss function, a pytree of parameters, a batch, and a learning rate,
# return the updated parameters and the loss *at the old parameters*.
#
# $$\theta_{t+1} = \theta_t - \eta \nabla_\theta \mathcal{L}(\theta_t, \text{batch})$$
#
# ### Rules
# - Use `jax.value_and_grad` — compute the loss and gradient in **one** pass,
#   not two (`loss_fn(...)` followed by `jax.grad(loss_fn)(...)` does double work)
# - `params` is an arbitrary **pytree** (nested dicts/lists/tuples of arrays),
#   not a flat array — do not assume it is a single array
# - Differentiate with respect to `params` only, not the batch
# - The returned loss must be the loss **before** the update
#
# ### Signature
# ```python
# def sgd_step(loss_fn, params, batch, lr):
#     # loss_fn(params, batch) -> scalar
#     # returns (new_params, loss)
#     ...
# ```
#
# ### Why it matters
# Interviewers use this to check three things at once: that you reach for
# `value_and_grad` instead of calling grad separately, that you know gradients
# mirror the parameter pytree, and that you keep the step function pure so it
# can be wrapped in `jax.jit`.

# %%
# Install jax-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q jax-judge flax')
except ImportError:
    pass

# %%
import jax
import jax.numpy as jnp

print("JAX", jax.__version__, "|", jax.devices())

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def sgd_step(loss_fn, params, batch, lr):
    """One SGD step.

    Args:
        loss_fn: callable (params, batch) -> scalar loss
        params:  pytree of parameters
        batch:   whatever loss_fn expects as its second argument
        lr:      float learning rate

    Returns:
        (new_params, loss) where loss is measured at the OLD params
    """
    pass  # Replace this

# %%
# 🔍 Scratch cell — poke at your implementation
import jax.numpy as jnp

params = {"w": jnp.array([1.0, 2.0]), "b": jnp.array(0.5)}
batch = (jnp.array([[1.0, 0.0], [0.0, 1.0]]), jnp.array([1.0, 1.0]))


def loss_fn(p, b):
    x, y = b
    pred = x @ p["w"] + p["b"]
    return jnp.mean((pred - y) ** 2)


new_params, loss = sgd_step(loss_fn, params, batch, lr=0.1)
print("loss before step:", loss)
print("old params:", params)
print("new params:", new_params)

# %%
# ✅ SUBMIT — run this cell to check your solution
from jax_judge import check, hint, solution

check("grad_basics")

# hint("grad_basics")      # stuck? nudge without the answer
# solution("grad_basics")  # spoiler: the reference implementation
